# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
mydata = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
df=pd.read_csv(mydata)

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
training_set = df.iloc[:, 1: 2].values
training_set
# Out:
# array([[234.05],
#        [234.55],
#        [240.  ],
#        ...,
#        [121.8 ],
#        [120.3 ],
#        [122.1 ]])

# %%
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
x_train = []
y_train = []
for i in range(60, 2035):
    x_train.append(training_set_scaled[i - 60: i, 0])
    y_train.append(training_set_scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(x_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 15s 130ms/step - loss: 0.0089
# Epoch 2/100
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0029
# Epoch 3/100
# 62/62 [==============================] - 8s 124ms/step - loss: 0.0029
# Epoch 4/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0028
# Epoch 5/100
# 62/62 [==============================] - 8s 134ms/step - loss: 0.0023
# Epoch 6/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0022
# Epoch 7/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0021
# Epoch 8/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0021
# Epoch 9/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0019
# Epoch 10/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0020
# Epoch 11/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0017
# Epoch 12/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0021
# Epoch 13/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0016
# Epoch 15/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0017
# Epoch 16/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0015
# Epoch 17/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0014
# Epoch 18/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0014
# Epoch 19/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0016
# Epoch 20/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0016
# Epoch 21/100
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0013
# Epoch 22/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0015
# Epoch 23/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0013
# Epoch 24/100
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0012
# Epoch 25/100
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0012
# Epoch 26/100
# 62/62 [==============================] - 7s 119ms/step - loss: 0.0010
# Epoch 27/100
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0013
# Epoch 28/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0011
# Epoch 29/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 30/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0010
# Epoch 31/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 32/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 33/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0011
# Epoch 34/100
# 62/62 [==============================] - 8s 122ms/step - loss: 8.4829e-04
# Epoch 35/100
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0011
# Epoch 36/100
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0012
# Epoch 37/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.6253e-04
# Epoch 38/100
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0010
# Epoch 39/100
# 62/62 [==============================] - 8s 121ms/step - loss: 9.3925e-04
# Epoch 40/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0011
# Epoch 41/100
# 62/62 [==============================] - 8s 122ms/step - loss: 9.9592e-04
# Epoch 42/100
# 62/62 [==============================] - 7s 120ms/step - loss: 9.0978e-04
# Epoch 43/100
# 62/62 [==============================] - 8s 122ms/step - loss: 9.1694e-04
# Epoch 44/100
# 62/62 [==============================] - 8s 122ms/step - loss: 9.7841e-04
# Epoch 45/100
# 62/62 [==============================] - 8s 121ms/step - loss: 9.1495e-04
# Epoch 46/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.6687e-04
# Epoch 47/100
# 62/62 [==============================] - 8s 123ms/step - loss: 9.3302e-04
# Epoch 48/100
# 62/62 [==============================] - 8s 123ms/step - loss: 8.4518e-04
# Epoch 49/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.7275e-04
# Epoch 50/100
# 62/62 [==============================] - 8s 122ms/step - loss: 8.8595e-04
# Epoch 51/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.1349e-04
# Epoch 52/100
# 62/62 [==============================] - 8s 122ms/step - loss: 8.6059e-04
# Epoch 53/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.3585e-04
# Epoch 54/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.3116e-04
# Epoch 55/100
# 62/62 [==============================] - 8s 123ms/step - loss: 7.9431e-04
# Epoch 56/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.9027e-04
# Epoch 57/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.0601e-04
# Epoch 58/100
# 62/62 [==============================] - 7s 121ms/step - loss: 7.5411e-04
# Epoch 59/100
# 62/62 [==============================] - 8s 121ms/step - loss: 8.3352e-04
# Epoch 60/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.7698e-04
# Epoch 61/100
# 62/62 [==============================] - 7s 120ms/step - loss: 6.9762e-04
# Epoch 62/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.6428e-04
# Epoch 63/100
# 62/62 [==============================] - 8s 123ms/step - loss: 8.1650e-04
# Epoch 64/100
# 62/62 [==============================] - 8s 124ms/step - loss: 7.4124e-04
# Epoch 65/100
# 62/62 [==============================] - 8s 125ms/step - loss: 7.4150e-04
# Epoch 66/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.7984e-04
# Epoch 67/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7.5976e-04
# Epoch 68/100
# 62/62 [==============================] - 7s 121ms/step - loss: 7.9357e-04
# Epoch 69/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.2461e-04
# Epoch 70/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.4452e-04
# Epoch 71/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.7095e-04
# Epoch 72/100
# 62/62 [==============================] - 7s 121ms/step - loss: 6.9458e-04
# Epoch 73/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.9135e-04
# Epoch 74/100
# 62/62 [==============================] - 7s 120ms/step - loss: 6.9351e-04
# Epoch 75/100
# 62/62 [==============================] - 7s 120ms/step - loss: 8.3802e-04
# Epoch 76/100
# 62/62 [==============================] - 7s 118ms/step - loss: 5.8086e-04
# Epoch 77/100
# 62/62 [==============================] - 7s 118ms/step - loss: 6.5372e-04
# Epoch 78/100
# 62/62 [==============================] - 7s 118ms/step - loss: 6.7501e-04
# Epoch 79/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.3064e-04
# Epoch 80/100
# 62/62 [==============================] - 7s 119ms/step - loss: 6.0888e-04
# Epoch 81/100
# 62/62 [==============================] - 7s 120ms/step - loss: 6.7950e-04
# Epoch 82/100
# 62/62 [==============================] - 7s 120ms/step - loss: 6.9477e-04
# Epoch 83/100
# 62/62 [==============================] - 7s 120ms/step - loss: 6.7587e-04
# Epoch 84/100
# 62/62 [==============================] - 7s 120ms/step - loss: 6.6568e-04
# Epoch 85/100
# 62/62 [==============================] - 15s 247ms/step - loss: 6.2399e-04
# Epoch 86/100
# 62/62 [==============================] - 8s 122ms/step - loss: 7.6718e-04
# Epoch 87/100
# 62/62 [==============================] - 7s 121ms/step - loss: 6.5528e-04
# Epoch 88/100
# 62/62 [==============================] - 8s 125ms/step - loss: 6.2248e-04
# Epoch 89/100
# 62/62 [==============================] - 8s 124ms/step - loss: 6.6554e-04
# Epoch 90/100
# 62/62 [==============================] - 8s 125ms/step - loss: 6.3440e-04
# Epoch 91/100
# 62/62 [==============================] - 8s 128ms/step - loss: 6.0662e-04
# Epoch 92/100
# 62/62 [==============================] - 9s 151ms/step - loss: 6.9736e-04
# Epoch 93/100
# 62/62 [==============================] - 10s 160ms/step - loss: 6.9026e-04
# Epoch 94/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.0314e-04
# Epoch 95/100
# 62/62 [==============================] - 7s 119ms/step - loss: 6.4531e-04
# Epoch 96/100
# 62/62 [==============================] - 7s 121ms/step - loss: 6.6246e-04
# Epoch 97/100
# 62/62 [==============================] - 8s 121ms/step - loss: 5.8788e-04
# Epoch 98/100
# 62/62 [==============================] - 8s 125ms/step - loss: 6.0090e-04
# Epoch 99/100
# 62/62 [==============================] - 7s 119ms/step - loss: 5.7937e-04
# Epoch 100/100
# 62/62 [==============================] - 7s 119ms/step - loss: 6.5803e-04

# %%
data_test =df=pd.read_csv(mydata)
real_stock_price = data_test.iloc[:, 1:2].values

# %%
data_total = pd.concat((df['Open'], data_test['Open']), axis = 0)
inputs = data_total[len(data_total) - len(data_test) - 60:].values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)

# %%
x_test = []
for i in range(60, 76):
    x_test.append(inputs[i - 60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predicted_stock_price = regressor.predict(x_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
plt.plot(real_stock_price, color = 'black', label = 'Tata Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Tata Stock Price')
plt.title('Tata Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel = ('Tata Stock Price')
plt.legend()
plt.show()
